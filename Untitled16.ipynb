# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth6921/Books-Python/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/hotel_bookings[1].csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.sample()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 33102  Resort Hotel            0          9               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 33102           February                         7                         14
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 33102                        0                     1       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 33102    No Deposit  250.0     NaN                    0     Transient  60.0
#
#        required_car_parking_spaces  total_of_special_requests  \
# 33102                            0                          0
#
#        reservation_status reservation_status_date
# 33102           Check-Out               2/15/2017
#
# [1 rows x 32 columns]

# %%
df.sample(10)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 57074    City Hotel            1        155               2016
# 59693    City Hotel            1         65               2016
# 56972    City Hotel            1         43               2016
# 33683  Resort Hotel            0         15               2017
# 52500    City Hotel            1        213               2016
# 60777    City Hotel            1         10               2016
# 12223  Resort Hotel            1        101               2017
# 33129  Resort Hotel            0        110               2017
# 45288    City Hotel            0         69               2015
# 8427   Resort Hotel            0        333               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 57074          September                        39                         18
# 59693           November                        45                          1
# ...

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.sample().sum()
# Out:
# hotel                             City Hotel
# is_canceled                                1
# lead_time                                114
# arrival_date_year                       2016
# arrival_date_month                    August
# arrival_date_week_number                  32
# arrival_date_day_of_month                  2
# stays_in_weekend_nights                    0
# stays_in_week_nights                       2
# adults                                     2
# children                                 3.0
# babies                                     0
# meal                                      BB
# country                                  PRT
# market_segment                     Online TA
# distribution_channel                   TA/TO
# is_repeated_guest                          0
# previous_cancellations                     0
# previous_bookings_not_canceled             0
# reserved_room_type                         G
# assigned_room_type                         G
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
df.describe().sum()
# Out:
# is_canceled                       119392.853335
# lead_time                         120584.874513
# arrival_date_year                 131487.864030
# arrival_date_week_number          119566.770311
# arrival_date_day_of_month         119493.579071
# stays_in_weekend_nights           119413.926212
# stays_in_week_nights              119450.408587
# adults                            119453.435664
# children                          119396.502451
# babies                            119400.105385
# is_repeated_guest                 119391.207679
# previous_cancellations            119416.931454
# previous_bookings_not_canceled    119463.634534
# booking_changes                   119411.873430
# agent                             104035.467929
# company                             8177.921750
# days_in_waiting_list              119800.915870
# adr                               125225.851912
# required_car_parking_spaces       119398.307809
# total_of_special_requests         119397.364161
# ...

# %%
import numpy as np

# %%
labels=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(data=sample_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(data=sample_list,index=labels)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %%
pd.Series(sample_list,array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['rk','kr','pk','rp'])
sports1
# Out:
# rk    1
# kr    2
# pk    3
# rp    4
# dtype: int64

# %%
sports1['rk']
# Out:
# 1

# %%
sports1[['rk','rp']]
# Out:
# rk    1
# rp    4
# dtype: int64

# %%
sports2=pd.Series([1,2,3,4],index=['rk','kr','pr','rp'])
sports2
# Out:
# rk    1
# kr    2
# pr    3
# rp    4
# dtype: int64

# %%
sports1+sports2
# Out:
# kr    4.0
# pk    NaN
# pr    NaN
# rk    2.0
# rp    8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns= 'rk kp sd gf hg'.split())
df1
# Out:
#          rk        kp        sd        gf        hg
# A  0.093775  0.839931  0.168914  0.261887  0.500243
# B  0.849832  0.627857  0.869874  0.946430  0.543639
# C  0.783308  0.577293  0.921441  0.884815  0.290240
# D  0.218824  0.099837  0.161210  0.668366  0.783018
# E  0.071062  0.252547  0.872238  0.696123  0.558015
# F  0.771338  0.604837  0.118728  0.206272  0.344452
# G  0.591689  0.328177  0.569321  0.258163  0.807554
# H  0.809208  0.158329  0.621547  0.451957  0.220941

# %%
df1['rk']
# Out:
# A    0.093775
# B    0.849832
# C    0.783308
# D    0.218824
# E    0.071062
# F    0.771338
# G    0.591689
# H    0.809208
# Name: rk, dtype: float64

# %%
df1[['rk','kp']]
# Out:
#          rk        kp
# A  0.093775  0.839931
# B  0.849832  0.627857
# C  0.783308  0.577293
# D  0.218824  0.099837
# E  0.071062  0.252547
# F  0.771338  0.604837
# G  0.591689  0.328177
# H  0.809208  0.158329

# %%
df1['pk']=df1['rk']+df1['kp']
df1
# Out:
#          rk        kp        sd        gf        hg        pk
# A  0.093775  0.839931  0.168914  0.261887  0.500243  0.933705
# B  0.849832  0.627857  0.869874  0.946430  0.543639  1.477689
# C  0.783308  0.577293  0.921441  0.884815  0.290240  1.360601
# D  0.218824  0.099837  0.161210  0.668366  0.783018  0.318661
# E  0.071062  0.252547  0.872238  0.696123  0.558015  0.323610
# F  0.771338  0.604837  0.118728  0.206272  0.344452  1.376175
# G  0.591689  0.328177  0.569321  0.258163  0.807554  0.919866
# H  0.809208  0.158329  0.621547  0.451957  0.220941  0.967537

# %%
df1['pk']=df1['rk']*df1['rk']
df1
# Out:
#          rk        kp        sd        gf        hg        pk
# A  0.093775  0.839931  0.168914  0.261887  0.500243  0.008794
# B  0.849832  0.627857  0.869874  0.946430  0.543639  0.722215
# C  0.783308  0.577293  0.921441  0.884815  0.290240  0.613571
# D  0.218824  0.099837  0.161210  0.668366  0.783018  0.047884
# E  0.071062  0.252547  0.872238  0.696123  0.558015  0.005050
# F  0.771338  0.604837  0.118728  0.206272  0.344452  0.594963
# G  0.591689  0.328177  0.569321  0.258163  0.807554  0.350095
# H  0.809208  0.158329  0.621547  0.451957  0.220941  0.654818

# %%
df2={'id':['100','101','102','103','104'],'name':['jon','king','killer','pill','jun'],'profile':[20,30,40,50,60]}
df=pd.DataFrame(df2)
df
# Out:
#     id    name  profile
# 0  100     jon       20
# 1  101    king       30
# 2  102  killer       40
# 3  103    pill       50
# 4  104     jun       60

# %%
df['id']
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# Name: id, dtype: object

# %%
df[['id','name']]
# Out:
#     id    name
# 0  100     jon
# 1  101    king
# 2  102  killer
# 3  103    pill
# 4  104     jun

# %%
df=df.drop('id',axis=1)
df
# Out:
#      name  profile
# 0     jon       20
# 1    king       30
# 2  killer       40
# 3    pill       50
# 4     jun       60

# %%
df.drop(3)

# %%
df.drop(2,axis=0)

# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth6921/Books-Python/blob/main/Yills_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/TaxiFare.csv")

# %%
df
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0       26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1       52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2       35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3       30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4       51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
# ...         ...     ...                      ...                  ...
# 49995   25:15.0    15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0     7.5  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0     6.9  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0     4.5  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0    10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# ...

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.dtypes
# Out:
# unique_id                object
# amount                  float64
# date_time_of_pickup      object
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger           int64
# dtype: object

# %%
df.isnull()
# Out:
#        unique_id  amount  date_time_of_pickup  longitude_of_pickup  \
# 0          False   False                False                False
# 1          False   False                False                False
# 2          False   False                False                False
# 3          False   False                False                False
# 4          False   False                False                False
# ...          ...     ...                  ...                  ...
# 49995      False   False                False                False
# 49996      False   False                False                False
# 49997      False   False                False                False
# 49998      False   False                False                False
# 49999      False   False                False                False
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0                   False                 False                False
# ...

# %%
df.sample(10)
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 15608   28:00.0    9.00  2014-03-08 15:28:00 UTC           -73.977975
# 10867   55:00.0    5.00  2013-09-30 07:55:00 UTC           -73.999738
# 44120   16:00.0   49.57  2010-10-21 19:16:00 UTC           -73.776708
# 49242   19:00.0   16.90  2010-08-16 17:19:00 UTC           -74.011417
# 26615   00:00.0    8.50  2014-01-09 13:00:00 UTC           -73.981235
# 41384   38:46.0    7.70  2009-09-05 00:38:46 UTC           -73.987546
# 47626   06:00.0    6.50  2011-10-30 20:06:00 UTC           -73.997665
# 30005   52:00.0   96.00  2012-05-07 18:52:00 UTC           -73.892575
# 41644   33:00.0   15.50  2014-08-21 08:33:00 UTC           -74.007547
# 35839   20:54.0    6.50  2009-09-03 14:20:54 UTC           -73.996469
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 15608           40.745730            -73.969870            40.766355
# ...

# %%
df.sample().sum()
# Out:
# unique_id                               15:37.0
# amount                                      6.0
# date_time_of_pickup     2014-07-06 22:15:37 UTC
# longitude_of_pickup                  -73.791995
# latitude_of_pickup                    40.645555
# longitude_of_dropoff                 -73.791995
# latitude_of_dropoff                   40.645555
# no_of_passenger                               2
# dtype: object

# %%
df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# ...

# %%
df.describe(include='all')
# Out:
#        unique_id        amount      date_time_of_pickup  longitude_of_pickup  \
# count      50000  50000.000000                    50000         50000.000000
# unique      3597           NaN                    49555                  NaN
# top      26:00.0           NaN  2011-09-03 01:30:00 UTC                  NaN
# freq         457           NaN                        3                  NaN
# mean         NaN     11.364171                      NaN           -72.509756
# std          NaN      9.685557                      NaN            10.393860
# min          NaN     -5.000000                      NaN           -75.423848
# 25%          NaN      6.000000                      NaN           -73.992062
# 50%          NaN      8.500000                      NaN           -73.981840
# 75%          NaN     12.500000                      NaN           -73.967148
# max          NaN    200.000000                      NaN            40.783472
#
# ...

# %%
df.describe().sum()
# Out:
# amount                  50243.049729
# longitude_of_pickup     49681.302678
# latitude_of_pickup      50495.489974
# longitude_of_dropoff    49672.164921
# latitude_of_dropoff     50137.605711
# no_of_passenger         50012.957035
# dtype: float64

# %%
sns.countplot(x="longitude_of_pickup",data=df)
# Out:
# <Axes: xlabel='longitude_of_pickup', ylabel='count'>

# %%
sns.countplot(x="amount",data=df)
# Out:
# <Axes: xlabel='amount', ylabel='count'>

# %%
df.hist(figsize=(13,10))
plt.show()

# %%
sns.boxplot(x="amount",hue="unique_id",data=df)
# Out:
# <Axes: xlabel='amount'>

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-18-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                         amount  longitude_of_pickup  latitude_of_pickup  \
# amount                1.000000             0.005944           -0.007338
# longitude_of_pickup   0.005944             1.000000           -0.950588
# latitude_of_pickup   -0.007338            -0.950588            1.000000
# longitude_of_dropoff  0.004286             0.956131           -0.911123
# latitude_of_dropoff  -0.005442            -0.946968            0.928189
# no_of_passenger       0.016583            -0.005604            0.003237
#
#                       longitude_of_dropoff  latitude_of_dropoff  \
# amount                            0.004286            -0.005442
# longitude_of_pickup               0.956131            -0.946968
# ...

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
plt.show()

# %%
sns.pairplot(df,diag_kind="kde")

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (50000, 8)

# %%
df["date_time_of_pickup"]=df["date_time_of_pickup"].replace(to_replace="??",value=np.nan)
df["date_time_of_pickup"]=df["date_time_of_pickup"].astype(object)
df["date_time_of_pickup"]
# Out:
# 0        2009-06-15 17:26:21 UTC
# 1        2010-01-05 16:52:16 UTC
# 2        2011-08-18 00:35:00 UTC
# 3        2012-04-21 04:30:42 UTC
# 4        2010-03-09 07:51:00 UTC
#                   ...
# 49995    2013-06-12 23:25:15 UTC
# 49996    2015-06-22 17:19:18 UTC
# 49997    2011-01-30 04:53:00 UTC
# 49998    2012-11-06 07:09:00 UTC
# 49999    2010-01-13 08:13:14 UTC
# Name: date_time_of_pickup, Length: 50000, dtype: object

# %%
df.dtypes
# Out:
# unique_id                object
# amount                  float64
# date_time_of_pickup      object
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger           int64
# dtype: object

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model1=DecisionTreeRegressor()

# %%
features = ['unique_id','amount','longitude_of_pickup','latitude_of_pickup','no_of_passenger']
X = df.loc[:, features]
y = df.loc[:, ['no_of_passenger']]
X
# Out:
#       unique_id  amount  longitude_of_pickup  latitude_of_pickup  \
# 0       26:21.0     4.5           -73.844311           40.721319
# 1       52:16.0    16.9           -74.016048           40.711303
# 2       35:00.0     5.7           -73.982738           40.761270
# 3       30:42.0     7.7           -73.987130           40.733143
# 4       51:00.0     5.3           -73.968095           40.768008
# ...         ...     ...                  ...                 ...
# 49995   25:15.0    15.0           -73.999973           40.748531
# 49996   19:18.0     7.5           -73.984756           40.768211
# 49997   53:00.0     6.9           -74.002698           40.739428
# 49998   09:00.0     4.5           -73.946062           40.777567
# 49999   13:14.0    10.9           -73.932603           40.763805
#
#        no_of_passenger
# 0                    1
# 1                    1
# 2                    2
# 3                    1
# 4                    1
# ...                ...
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size =5)

# %%
model1 = DecisionTreeRegressor(max_depth = 2, random_state=5)
model1
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=5)

# %%
model1.fit(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7ea3088e6cdc> in <cell line: 1>()
# ----> 1 model1.fit(X_test, y_test)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1245         """
#    1246
# -> 1247         super().fit(
#    1248             X,
#    1249             y,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
#     187                 X, y, validate_separately=(check_X_params, check_y_params)
#     188             )
#
# ...
